# %%
"""Name : Ved Lakkad
Enrollment No. : 2302031700019
ID : 8118
Phone number : 9974876307
Question : 4"""
# Out:
# 'Name : Ved Lakkad\nEnrollment No. : 2302031700019\nID : 8118\nPhone number : 9974876307\nQuestion : 4'

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('Ch3.ClevelandData.xlsx')
df
# Out:
#      63  1  1.1  145  233  1.2  2  150  0  2.3  3 0.1  6  0.2
# 0    67  1    4  160  286    0  2  108  1  1.5  2   3  3    1
# 1    67  1    4  120  229    0  2  129  1  2.6  2   2  7    1
# 2    37  1    3  130  250    0  0  187  0  3.5  3   0  3    0
# 3    41  0    2  130  204    0  2  172  0  1.4  1   0  3    0
# 4    56  1    2  120  236    0  0  178  0  0.8  1   0  3    0
# ..   .. ..  ...  ...  ...  ... ..  ... ..  ... ..  .. ..  ...
# 297  45  1    1  110  264    0  0  132  0  1.2  2   0  7    1
# 298  68  1    4  144  193    1  0  141  0  3.4  2   2  7    1
# 299  57  1    4  130  131    0  0  115  1  1.2  2   1  7    1
# 300  57  0    2  130  236    0  2  174  0  0.0  2   1  3    1
# 301  38  1    3  138  175    0  0  173  0  0.0  1   ?  3    0
#
# [302 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# BOXPLOT
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title("Boxplot : ")
plt.show()

# %%
# DATA CLEANING:
# missing values check krne ke liye
print(df.isnull().sum())

# missing values htane ke liye
df.dropna(inplace=True)

# non-numeric values htane ke liye
df.replace('?', np.nan, inplace=True)

# HEATMAP CODE:
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Heatmap of Correlations")
plt.show()
# Out:
# 63     0
# 1      0
# 1.1    0
# 145    0
# 233    0
# 1.2    0
# 2      0
# 150    0
# 0      0
# 2.3    0
# 3      0
# 0.1    0
# 6      0
# 0.2    0
# dtype: int64

# %%
sns.pairplot(df)
plt.title("Scatter Matrix of the Dataset")
plt.show()
